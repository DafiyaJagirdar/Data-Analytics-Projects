# %% [markdown]
# # The weather Dataset project

# %% [raw]
# Summary:
#     In this project we see the wheather condition at perticular location . we see Temprature , Temprature Dew point,
#     Relative Humidity, Wind speed, Visiblity, pressure and conditions with the help of pandas DataFrame

# %%
import io
# %cd "C:\Users\dafiy\OneDrive\Desktop\Dafiya\Data Analytics\Projects\wheather"
# Out:
# C:\Users\dafiy\OneDrive\Desktop\Dafiya\Data Analytics\Projects\wheather

# %%
import pandas as pd
wd=pd.read_csv("weather.csv")

# %% [markdown]
# # Analyzing DataFrames

# %%
wd.head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
wd.tail(10)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 356      3.4     15.0       0.8          4.8      11.7           S
# 357      3.2     18.0       0.0          7.4      12.2         SSE
# 358      0.9     20.7       0.0          5.4       8.4         NNW
# 359      3.3     25.5       0.0          5.2      10.8           N
# 360      7.9     26.1       0.0          6.8       3.5         NNW
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 356           70.0          S          S          35.0  ...           24
# 357           48.0        SSE          S          26.0  ...           25
# ...

# %%
wd.shape  #it shows total number of rows and columns in the data
# Out:
# (366, 22)

# %%
#we will see the index of this data
wd.index

#so the starting index is 0 and last index is 366
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
wd.columns  #with this help of command we sill see the column names
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
wd.dtypes  #if we want to see what type of data we used in the existing data then we used dtypes command
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
wd['MinTemp'].unique()   #if we wants to check the unique values on single column not on whole frame then
# Out:
# array([ 8. , 14. , 13.7, 13.3,  7.6,  6.2,  6.1,  8.3,  8.8,  8.4,  9.1,
#         8.5, 10.1, 12.1, 12.4, 13.8, 11.7, 15.6, 15.3, 16.4, 12.8, 12. ,
#        15.4, 12.9, 15.1, 13.6, 11.6, 16.6, 14.5, 16.3, 17.2, 16.5, 15. ,
#        14.9, 11.8,  9.6,  8.9, 15.5, 10.8,  7.5, 12.6, 14.8, 19.9,  9.2,
#        11.3,  9.8, 14.3, 14.4, 15.9, 16.7, 17.5, 14.7, 20.9, 17. , 16. ,
#        17.9, 15.2, 10. ,  9.9, 10.3, 12.7, 13.2, 18. , 17.6, 17.1, 18.2,
#        16.8, 10.4,  8.6, 11.2, 11.4, 11.5, 13. ,  7.7,  4.4,  7.4,  9.5,
#        12.5, 13.9, 12.3, 13.1,  7.1,  4.2,  3.5,  5.3,  7. ,  0.4,  3.2,
#         5.9,  8.1,  6.9,  5.6,  7.2,  5.4,  6.3,  7.9,  2.4,  2.5,  5. ,
#         3.8,  4.3, -2.1, -1.8,  2.1,  0.5, -0.9, -0.2,  0.1,  1.5,  9.4,
#         1.3,  2.2, -0.4,  4.5, -2.7,  0.3,  1.2, -0.3,  4.7,  4.9,  1.4,
#        -0.1,  0.6,  4.6, 10.6,  7.8, 10.2,  7.3,  8.7,  1. ,  6.4,  4. ,
#         0.9,  0.8, -1.5,  6.6, -1.6, -3.1, -0.6,  3. ,  2.9, -1.3,  1.8,
# ...

# %%
#Total no of unique values in each column.we can used both for single column or for whole dataframe
#--> we have applied for whole DataFrame
wd.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
wd['MaxTemp'].nunique()  #if we want to see the total number of unique values on maxTemp column
# Out:
# 187

# %%
wd['MaxTemp'].count()  #here it will shows the total number of non-null values in MaxTemp.
#we can use count for single columns as well as for whole Dataframe
# Out:
# 366

# %%
wd.count()  #here we will see the total number of non-null values for whole frame
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
wd['Sunshine'].value_counts()
#this value_count shows all the unique values with count as you can see at last there are 114 unique value are there 
#it is note that it works only on single column not on whole DataFrame
# Out:
# Sunshine
# 0.0     10
# 8.4      8
# 8.1      8
# 8.9      8
# 5.6      7
#         ..
# 0.1      1
# 13.5     1
# 6.9      1
# 13.3     1
# 5.3      1
# Name: count, Length: 114, dtype: int64

# %%
wd.info()  #here you can see the total information of the existing dataframe such as column name calues and datatypes ,index range
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %% [markdown]
# # Now we will perform some operations on this dataframe

# %% [raw]
# 1.Find all the unique 'Wind Speed' at 3pm, values in the data.

# %%
#here all the unique values in windspeed 3pm
all_unique=wd['WindSpeed3pm'].unique()
print(all_unique)
#we will see how much unique value present at windspeed
total_uniq=wd['WindSpeed3pm'].nunique()
print("total unique value of windspeed at 3pm is: ", total_uniq)
# Out:
# [20 17  6 24 28 26  9 15  7 19 11 13 31 22 35 30 48  4 37 33  0  2 39 52
#  41 50]
# total unique value of windspeed at 3pm is:  26

# %% [markdown]
# # Filtering

# %%
wd.head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
wd[wd.RainToday == 'No'] #it will filter only those columns in which there is no rain
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 6        6.1     18.2       0.2          4.2       8.4          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # groupby()

# %%
#same filtering by using group by but now will take raining today should be yes
wd.groupby('RainToday').get_group('Yes')
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 327      7.8     16.2      17.4          6.4       7.9          NW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 339     10.3     21.3       3.0          4.2       6.7         NNW
# 341      0.3     16.0       8.2          5.4      11.8          NW
# 348     11.9     21.1      13.2          6.6       NaN          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# ...

# %% [raw]
# 3) Find the number of times when the 'Wind Speed at 9 was exactly 4 km/h'.

# %%
wd[wd.WindSpeed9am == 4.0]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunlight WindGustDir  \
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 18      12.4     32.3       0.6          7.4      13.0           E
# 49      12.6     23.1       3.4          1.6       2.3         NNW
# 72      20.9     35.7       0.0         13.8       6.9          SW
# 86      12.7     28.8       0.0          7.4       9.0         NNE
# 87      13.2     31.3       0.0          6.6      11.6         WSW
# 88      15.3     33.2       0.0          9.4      13.2         NNW
# 112     16.3     24.8       1.8          7.8       3.8           S
# 117     13.0     28.2       0.0          5.0      11.6          NW
# 136     11.3     32.3       0.0          9.4      11.4          NE
# 139     15.1     26.2       0.0          9.0       9.8          NE
# 161      7.2     22.9       0.0          2.2       9.5           E
# 193      9.4     19.2       0.0          2.2       7.7         NaN
# ...

# %% [raw]
#  4) Find out all the Null Values in the data.

# %%
wd.isnull().sum()  #it will show the total not null values of each columns
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
#another function to check null values
wd.notnull().sum()  #there is no null value in whole data
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %% [raw]
# 4) Rename the column name 'Sunshine' of the dataframe to 'sunlight'.

# %%
wd.rename(columns = {'Sunshine' :'Sunlight'},inplace=True)

# %%
wd.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunlight WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [raw]
# 5)  What is the mean 'Humidity3pm' ,'MinTemp','MaxTemp' ?

# %%
Humid_mean=wd.Humidity3pm.mean()
print("The Average Humdity at 3pm is: ",Humid_mean)
print()
maxTemp_mean=wd.MaxTemp.mean()
print("The Average of maximum Temprature is: ",maxTemp_mean)
print()
minTemp_mean=wd.MinTemp.mean()
print("The Average of Minimum Temprature is: ",minTemp_mean)
print()
# Out:
# The Average Humdity at 3pm is:  44.51912568306011
#
# The Average of maximum Temprature is:  20.550273224043714
#
# The Average of Minimum Temprature is:  7.265573770491804

# %% [raw]
# 6) What is the Standard Deviation of 'Rainfall'  in this data?

# %%
wd.Rainfall.std()
# Out:
# 4.225799585804068

# %% [raw]
# 7) What is the Variance of 'WindSpeed9am' in this data ?

# %%
wd.WindSpeed9am.var()
# Out:
# 63.23317408692683

# %%
wd['WindSpeed9am'].var()  #another way to find variance its just another pattern
# Out:
# 63.23317408692683

# %% [raw]
# 8) Find all instances when Risk is high.

# %%
wd[wd.RISK_MM>=15]  #filtering
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunlight WindGustDir  \
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# 21      16.4     19.4       0.4          9.2       0.0           E
# 29      13.6     24.1       0.4          2.6       0.5         NNW
# 51      19.9     22.0      11.0          4.4       5.9         NNW
# 78      15.1     20.4       0.0          9.6       0.1         ESE
# 98      14.5     24.2       0.0          6.8       5.9         SSW
# 145     13.1     17.4       6.4          2.8       0.0         NNW
# 249      3.0     11.1       0.8          1.4       0.2           W
# 262     -1.1     11.0       0.2          1.8       0.0         WNW
# 326      3.2     21.9       0.0          6.8       5.2          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 2             85.0          N        NNE           6.0  ...           69
# ...

# %% [raw]
# 8) Find all instances of no rain tomorrow.

# %%
wd[wd['RainTomorrow'].str.contains('No')]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunlight WindGustDir  \
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 6        6.1     18.2       0.2          4.2       8.4          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 4             50.0        SSE        ESE          20.0  ...           49
# ...

# %% [raw]
# 9) Find all the instances when minimum Temprature is above 11 and Sunlight is 6

# %%
wd[(wd['MinTemp']>11) & (wd['Sunlight']==6)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunlight WindGustDir  \
# 74      16.0     22.8       0.0         12.4       6.0           E
# 318     13.1     19.4       9.8          8.8       6.0         NNW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 74            50.0          E        ENE          13.0  ...           57
# 318           67.0          N         NW          39.0  ...           43
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 74        1012.3       1012.3         8         6     17.0     21.6
# 318       1007.3       1006.0         7         1     16.7     18.2
#
#      RainToday  RISK_MM RainTomorrow
# 74          No      0.0           No
# 318        Yes      1.6          Yes
#
# [2 rows x 22 columns]

# %% [raw]
# 10) What is the Mean value of each column against each 'Pressure3pm ?

# %%
wd['Pressure3pm'].mean()
# Out:
# 1016.8103825136611

# %% [raw]
# 10) Minimum and maxium wind speed and also find min and maximum temprratue at morning

# %%
wind_speed_max=wd['WindGustSpeed'].max()
print("maximum wind speed is: ",wind_speed_max)
print()
wind_speed_min=wd['WindGustSpeed'].min()
print("minimum wind speed is: ",wind_speed_min)
print()

print("***Max and min Temprature****")
max_temp=wd['Temp9am'].max()
print("maximum Temprature in morning is: ",max_temp)
print()
min_temp=wd['Temp9am'].min()
print("minimum Temprature in morning is: ",min_temp)
print()
# Out:
# maximum wind speed is:  98.0
#
# minimum wind speed is:  13.0
#
# ***Max and min Temprature****
# maximum Temprature in morning is:  24.7
#
# minimum Temprature in morning is:  0.1

# %% [raw]
# 11) Find all the records where wind direction at 3 is South west

# %%
wd[wd['WindDir3pm']=='SW']
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunlight WindGustDir  \
# 31      11.6     26.3       4.2          1.6      12.0         NNE
# 143     12.8     24.9       0.0          2.4       6.2         ENE
# 328      2.4     17.3       0.0          2.2      11.3           E
# 355      9.0     20.6       0.0          9.0       6.2         ENE
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 31            41.0          E         SW           6.0  ...           46
# 143           30.0        NNW         SW           6.0  ...           44
# 328           31.0        SSE         SW           4.0  ...           33
# 355           39.0          S         SW          11.0  ...           28
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 31        1013.9       1009.5         2         2     16.7     25.2
# 143       1023.2       1019.3         7         6     15.5     24.2
# ...

# %% [raw]
# 12) find all the instances when there is raining or pressure at morning is above 1050

# %%
wd[(wd['RainToday']=='Yes') | (wd['Pressure9am']>1050)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunlight WindGustDir  \
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 327      7.8     16.2      17.4          6.4       7.9          NW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 339     10.3     21.3       3.0          4.2       6.7         NNW
# 341      0.3     16.0       8.2          5.4      11.8          NW
# 348     11.9     21.1      13.2          6.6       NaN          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# ...

# %% [raw]
# 13) find all the instances when:
#     a- its raining and wind speed is greater than 50
#     or
#     b-Temprature at 3 is above 11

# %%
wd[(wd['RainToday']=='Yes') & (wd['WindGustSpeed']>70) | (wd['Temp3pm']>25)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunlight WindGustDir  \
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 11       8.5     27.3       0.2          7.2      12.5           E
# 12      10.1     27.9       0.0          7.2      13.0         WNW
# 13      12.1     30.9       0.0          6.2      12.4          NW
# ..       ...      ...       ...          ...       ...         ...
# 360      7.9     26.1       0.0          6.8       3.5         NNW
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# ...
